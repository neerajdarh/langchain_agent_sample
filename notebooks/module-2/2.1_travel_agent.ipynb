# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()
# Out:
# D:\langchain_acedemy\lca-lc-foundations\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "google_genai:gemini-2.5-flash",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from Pune to Delhi on May 31st, 2026. don't consume much token, just give me flight details like airline name and time.")]},
    config
    )
# Out:
# Key 'additionalProperties' is not supported in schema, ignoring
# Key '$schema' is not supported in schema, ignoring
# Key 'additionalProperties' is not supported in schema, ignoring
# Key '$schema' is not supported in schema, ignoring
# Key 'additionalProperties' is not supported in schema, ignoring
# Key '$schema' is not supported in schema, ignoring
# Key 'additionalProperties' is not supported in schema, ignoring
# Key '$schema' is not supported in schema, ignoring

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="Get me a direct flight from Pune to Delhi on May 31st. don't consume much token, just give me flight details like airline name and time.", additional_kwargs={}, response_metadata={}, id='dca661fb-d878-4f43-ba4e-1a5dc1b77b1d'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'search-flight', 'arguments': '{"departureDate": "31/05/2024", "flyTo": "Delhi", "flyFrom": "Pune"}'}, '__gemini_function_call_thought_signatures__': {'56ac325c-077a-41a2-9bf7-0e2696b056a6': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e54bc-e4f3-7f43-aa9c-20f026aff53a-0', tool_calls=[{'name': 'search-flight', 'args': {'departureDate': '31/05/2024', 'flyTo': 'Delhi', 'flyFrom': 'Pune'}, 'id': '56ac325c-077a-41a2-9bf7-0e2696b056a6', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 1925, 'total_tokens': 3154, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1888}}),
#               HumanMessage(content="Get me a direct flight from Pune to Delhi on May 31st. don't consume much token, just give me flight details like airline name and time.", additional_kwargs={}, response_metadata={}, id='48180486-3132-4f3a-bce0-1db80ee941ab'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'search-flight', 'arguments': '{"flyFrom": "Pune", "departureDate": "31/05/2024", "flyTo": "Delhi"}'}, '__gemini_function_call_thought_signatures__': {'1f00fb81-7bc8-487b-9234-fb9c77a979c8': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e54bd-5b21-72a3-ba8b-a326904d40dc-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'Pune', 'departureDate': '31/05/2024', 'flyTo': 'Delhi'}, 'id': '1f00fb81-7bc8-487b-9234-fb9c77a979c8', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1302, 'output_tokens': 1750, 'total_tokens': 3052, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1713}}),
#               HumanMessage(content="Get me a direct flight from Pune to Delhi on May 31st, 2026. don't consume much token, just give me flight details like airline name and time.", additional_kwargs={}, response_metadata={}, id='86e5baf4-389c-4c32-8d2e-96b6bd8d1b84'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'search-flight', 'arguments': '{"departureDate": "31/05/2026", "flyFrom": "Pune", "flyTo": "Delhi"}'}, '__gemini_function_call_thought_signatures__': {'86bb3ba5-c07c-4704-80aa-403ee68587ce': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e54be-aeef-7fc0-8b38-2c4b97d3298a-0', tool_calls=[{'name': 'search-flight', 'args': {'departureDate': '31/05/2026', 'flyFrom': 'Pune', 'flyTo': 'Delhi'}, 'id': '86bb3ba5-c07c-4704-80aa-403ee68587ce', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1381, 'output_tokens': 215, 'total_tokens': 1596, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 178}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "PNQ",\n    "flyTo": "DEL",\n    "cityFrom": "Pune",\n    "cityTo": "New Delhi",\n    "departure": {\n      "utc": "2026-05-30T18:45:00.000Z",\n      "local": "2026-05-31T00:15:00.000"\n    },\n    "arrival": {\n      "utc": "2026-05-30T21:00:00.000Z",\n      "local": "2026-05-31T02:30:00.000"\n    },\n    "totalDurationInSeconds": 8100,\n    "durationInSeconds": 8100,\n    "price": 83,\n    "deepLink": "https://on.kiwi.com/zSQbD6",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "PNQ",\n    "flyTo": "DEL",\n    "cityFrom": "Pune",\n    "cityTo": "New Delhi",\n    "departure": {\n      "utc": "2026-05-30T19:05:00.000Z",\n      "local": "2026-05-31T00:35:00.000"\n    },\n    "arrival": {\n      "utc": "2026-05-30T21:30:00.000Z",\n      "local": "2026-05-31T03:00:00.000"\n    },\n    "totalDurationInSeconds": 8700,\n    "durationInSeconds": 8700,\n    "price": 73,\n    "deepLink": "https://on.kiwi.com/J5CUIZ",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "PNQ",\n    "flyTo": "DEL",\n    "cityFrom": "Pune",\n    "cityTo": "New Delhi",\n    "departure": {\n      "utc": "2026-05-30T19:25:00.000Z",\n      "local": "2026-05-31T00:55:00.000"\n    },\n    "arrival": {\n      "utc": "2026-05-30T21:45:00.000Z",\n      "local": "2026-05-31T03:15:00.000"\n    },\n    "totalDurationInSeconds": 8400,\n    "durationInSeconds": 8400,\n    "price": 72,\n    "deepLink": "https://on.kiwi.com/eW8DVR",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "PNQ",\n    "flyTo": "DEL",\n    "cityFrom": "Pune",\n    "cityTo": "New Delhi",\n    "departure": {\n      "utc": "2026-05-30T19:50:00.000Z",\n      "local": "2026-05-31T01:20:00.000"\n    },\n    "arrival": {\n      "utc": "2026-05-30T22:10:00.000Z",\n      "local": "2026-05-31T03:40:00.000"\n    },\n    "totalDurationInSeconds": 8400,\n    "durationInSeconds": 8400,\n    "price": 62,\n    "deepLink": "https://on.kiwi.com/moHo31",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "PNQ",\n    "flyTo": "DEL",\n    "cityFrom": "Pune",\n    "cityTo": "New Delhi",\n    "departure": {\n      "utc": "2026-05-30T19:50:00.000Z",\n      "local": "2026-05-31T01:20:00.000"\n    },\n    "arrival": {\n      "utc": "2026-05-30T22:10:00.000Z",\n      "local": "2026-05-31T03:40:00.000"\n    },\n    "totalDurationInSeconds": 8400,\n    "durationInSeconds": 8400,\n    "price": 66,\n    "deepLink": "https://on.kiwi.com/8lDrpl",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "PNQ",\n    "flyTo": "DEL",\n    "cityFrom": "Pune",\n    "cityTo": "New Delhi",\n    "departure": {\n      "utc": "2026-05-30T23:35:00.000Z",\n      "local": "2026-05-31T05:05:00.000"\n    },\n    "arrival": {\n      "utc": "2026-05-31T01:45:00.000Z",\n      "local": "2026-05-31T07:15:00.000"\n    },\n    "totalDurationInSeconds": 7800,\n    "durationInSeconds": 7800,\n    "price": 79,\n    "deepLink": "https://on.kiwi.com/99Kn0L",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "PNQ",\n    "flyTo": "DEL",\n    "cityFrom": "Pune",\n    "cityTo": "New Delhi",\n    "departure": {\n      "utc": "2026-05-31T00:25:00.000Z",\n      "local": "2026-05-31T05:55:00.000"\n    },\n    "arrival": {\n      "utc": "2026-05-31T03:00:00.000Z",\n      "local": "2026-05-31T08:30:00.000"\n    },\n    "totalDurationInSeconds": 9300,\n    "durationInSeconds": 9300,\n    "price": 76,\n    "deepLink": "https://on.kiwi.com/UHn10m",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "PNQ",\n    "flyTo": "DEL",\n    "cityFrom": "Pune",\n    "cityTo": "New Delhi",\n    "departure": {\n      "utc": "2026-05-31T02:10:00.000Z",\n      "local": "2026-05-31T07:40:00.000"\n    },\n    "arrival": {\n      "utc": "2026-05-31T04:35:00.000Z",\n      "local": "2026-05-31T10:05:00.000"\n    },\n    "totalDurationInSeconds": 8700,\n    "durationInSeconds": 8700,\n    "price": 78,\n    "deepLink": "https://on.kiwi.com/GI1KAZ",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "PNQ",\n    "flyTo": ...
#               AIMessage(content=[{'type': 'text', 'text': 'I found several direct flights from Pune to Delhi on May 31st, 2026. Please note that airline names are not available in the current results.\n\nHere are a few options:\n\n*   **Departure:** 01:20 (May 31st) **Arrival:** 03:40 (May 31st) **Duration:** 2h 20m **Price:** 62 EUR\n*   **Departure:** 05:05 (May 31st) **Arrival:** 07:15 (May 31st) **Duration:** 2h 10m **Price:** 79 EUR\n*   **Departure:** 14:45 (May 31st) **Arrival:** 16:45 (May 31st) **Duration:** 2h 0m **Price:** 85 EUR', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e54be-cd90-7962-b370-9a7d643a0742-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5332, 'output_tokens': 849, 'total_tokens': 6181, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 652}})]}

# %%
print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': 'I found several direct flights from Pune to Delhi on May 31st, 2026. Please note that airline names are not available in the current results.\n\nHere are a few options:\n\n*   **Departure:** 01:20 (May 31st) **Arrival:** 03:40 (May 31st) **Duration:** 2h 20m **Price:** 62 EUR\n*   **Departure:** 05:05 (May 31st) **Arrival:** 07:15 (May 31st) **Duration:** 2h 10m **Price:** 79 EUR\n*   **Departure:** 14:45 (May 31st) **Arrival:** 16:45 (May 31st) **Duration:** 2h 0m **Price:** 85 EUR', 'extras': {'signature': '...'}}]
