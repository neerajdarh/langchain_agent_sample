# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='google_genai:gemini-2.5-flash',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)
# Out:
# D:\langchain_acedemy\lca-lc-foundations\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'photo-1587474260584-136574528ed5.png', 'type': 'image/png', 'size': 686503, 'content': <memory at 0x000001F7E1FC9840>, 'last_modified': datetime.datetime(2026, 5, 23, 11, 7, 35, 896000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
from langchain.messages import HumanMessage
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# The image shows the **India Gate**, a prominent war memorial and landmark located in **New Delhi**, which is the capital of India.
#
# Here's more about New Delhi, the capital:
#
# **New Delhi: The Capital of India**
#
# 1.  **Identity and Location:**
#     *   New Delhi is the capital city of India and a district within the larger metropolis of Delhi.
#     *   It is located in the north-central part of India, on the Yamuna River.
#
# 2.  **History and Planning:**
#     *   Unlike many ancient Indian cities, New Delhi is a relatively modern, planned city. It was designed by British architects Sir Edwin Lutyens and Sir Herbert Baker.
#     *   It was inaugurated in 1931 as the new capital of British India, replacing Kolkata (Calcutta).
#     *   After India gained independence in 1947, New Delhi officially became the capital of the Republic of India.
#     *   The city is characterized by wide, tree-lined avenues, grand governmental buildings, and numerous green spaces, a legacy of its planned design.
#
# 3.  **Political and Administrative Hub:**
#     *   New Delhi serves as the seat of the Government of India.
#     *   It houses key institutions like the Rashtrapati Bhavan (President's Residence), Parliament House, the Supreme Court of India, and numerous ministries and government offices.
#     *   The India Gate (seen in the image) itself is a war memorial to 70,000 soldiers of the British Indian Army who died in World War I and the Third Anglo-Afghan War. Beneath its arch burns the Amar Jawan Jyoti, an eternal flame commemorating India's fallen soldiers.
#
# 4.  **Cultural and Historical Significance:**
#     *   While New Delhi is modern, it is part of the larger Delhi region, which has a rich history spanning millennia. Delhi has been the capital of various empires and kingdoms, leading to a wealth of historical monuments.
#     *   The city is a melting pot of cultures, reflecting India's diversity.
#     *   It boasts numerous UNESCO World Heritage Sites, including Humayun's Tomb, Qutub Minar, and the Red Fort (though the latter is in Old Delhi, it's part of the broader Delhi experience). Other significant sites include the Lotus Temple, Akshardham Temple, and Jantar Mantar.
#
# 5.  **Economy and Lifestyle:**
#     *   New Delhi is a major economic hub, a center for commerce, education, and technology.
#     *   It's known for its bustling markets (like Connaught Place and Chandni Chowk), diverse culinary scene, and vibrant arts and culture.
#     *   The city experiences extreme weather, with hot summers, cold winters, and a monsoon season.
#
# In summary, New Delhi is a dynamic and historically rich capital city that beautifully blends its colonial past, ancient heritage, and modern aspirations, making it a pivotal center for India's political, cultural, and economic life. The India Gate, as depicted in your image, stands as a proud symbol within this grand capital.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.72it/s]
# Done.

# %%
agent = create_agent(
    model='google_genai:gemini-2.5-flash',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       1 agent = create_agent(
#       2     model='google_genai:gemini-2.5-flash',
#       3 )
# ----> 5 multimodal_question = HumanMessage(content=[
#       6     {"type": "text", "text": "Tell me about this audio file"},
#       7     {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
#       8 ])
#      10 response = agent.invoke(
#      11     {"messages": [multimodal_question]}
#      12 )
#      14 print(response['messages'][-1].content)
#
# NameError: name 'HumanMessage' is not defined
